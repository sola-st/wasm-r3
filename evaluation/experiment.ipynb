# %%
short_case = [
    "boa",
    "funky-kart",
    "guiicons",
    "jsc",
    "mandelbrot",
    "rfxgen",
    "rguilayout",
    "rguistyler",
    "riconpacker",
    "sqlgui",
    "wamr#2450",
    "wamr#2789",
    "wamr#2861",
    "wamr#2862",
    "wasmedge#3018",
    "wasmedge#3019",
    "wasmedge#3057",
]
long_case = ["commanderkeen", "rtexviewer", "hydro", "wasmedge#3076"]

# !TEST_NAMES={','.join(short_case)} python eval_reduce.py wasm-slice # 5 mins
# !TEST_NAMES={','.join(long_case)} python eval_reduce.py wasm-slice # 1 hour
# Out:
# len(testset): 17
# Not interesting
# Not interesting
# Not interesting
# Not interesting
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Not interesting
# Not interesting
# Not interesting
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Not interesting
# Oracle command failed with exit code 1. Retrying... (Attempt 1/3)
# Not interesting
# Not interesting
# Oracle command failed with exit code 1. Retrying... (Attempt 2/3)
# Oracle command failed with exit code 1. Retrying... (Attempt 2/3)
# Not interesting
# Not interesting
# Not interesting
# Not interesting
# Not interesting
# ...

# %%
# !MAX_WORKER=1 python eval_reduce.py wasm-reduce

# %%
# !MAX_WORKER=1 python eval_reduce.py wasm-shrink
# Out:
# len(testset): 21
# Running in single thread mode
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# Interesting!
# CompletedProcess(args='timeout 10s wizard-0d6926f -no-names -mode=spc /home/don/wasm-r3/benchmarks/commanderkeen/commanderkeen.shrunken.wasm', returncode=10, stdout='!trap[STACK_OVERFLOW]\n', stderr='')
# CompletedProcess(args='timeout 5s wasmtime --invoke main /home/don/wasm-r3/benchmarks/commanderkeen/commanderkeen.shrunken.wasm', returncode=0, stdout='', stderr='')
# Interesting!
# Interesting!
