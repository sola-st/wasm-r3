# %%
import util
# !. ~/.bashrc && TEST_NAMES={','.join(short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-hybrid
# !. ~/.bashrc && TEST_NAMES={','.join(long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-hybrid
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
import util
# !. ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-reduce # 19m
# Out:
# len(testset): 9
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |input: |input: |input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/hydro/hydro.wasm|input: |input: |wasm-reduce
# |input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/wasmedge#3019/wasmedge#3019.wasm|input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/wamr#2789/wamr#2789.wasm/home/doehyunbaek/wasm-r3/evaluation/benchmarks/rtexviewer/rtexviewer.wasm/home/doehyunbaek/wasm-r3/evaluation/benchmarks/wamr#2450/wamr#2450.wasm
# /home/doehyunbaek/wasm-r3/evaluation/benchmarks/wamr#2862/wamr#2862.wasm|input:
# /home/doehyunbaek/wasm-r3/evaluation/benchmarks/wasmedge#3018/wasmedge#3018.wasm
#
# |test: |test: |test:
# ...

# %%
import util
# !. ~/.bashrc && TEST_NAMES={','.join(util.long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-reduce > reduce_long.log
# Out:
# nohup: ignoring input and redirecting stderr to stdout
