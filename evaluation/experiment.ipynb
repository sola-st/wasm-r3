# %%
import util
# !. ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-hybrid-all # 9.5 min
# !. ~/.bashrc && TEST_NAMES={','.join(util.long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-hybrid-all
# Out:
# nohup: ignoring input and appending output to 'nohup.out'

# %%
import util
# !. ~/.bashrc && TEST_NAMES={','.join(util.new_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-reduce # 19m
# Out:
# len(testset): 8
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |applying timeout: 60
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |wasm-reduce
# |input: |wasm-reduce
# |input: |input: |wasm-reduce
# |input: |input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/ffmpeg/ffmpeg.wasm/home/doehyunbaek/wasm-r3/evaluation/benchmarks/bullet/bullet.wasm|input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/pathfinding/pathfinding.wasm|input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/parquet/parquet.wasm|input: /home/doehyunbaek/wasm-r3/evaluation/benchmarks/sandspiel/sandspiel.wasm
# /home/doehyunbaek/wasm-r3/evaluation/benchmarks/jqkungfu/jqkungfu.wasm
# /home/doehyunbaek/wasm-r3/evaluation/benchmarks/pacalc/pacalc.wasm
#
# /home/doehyunbaek/wasm-r3/evaluation/benchmarks/figma-startpage/figma-startpage.wasm|test:
# |test:
# |test:
# ...

# %%
import util
# !. ~/.bashrc && TEST_NAMES={','.join(util.long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-reduce > reduce_long.log
# Out:
# nohup: ignoring input and redirecting stderr to stdout

# %%
import util
# 51m for short cases
# !. ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-hybrid-target
# !. ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-hybrid-remain

# !. ~/.bashrc && TEST_NAMES={','.join(util.long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-hybrid-target
# !. ~/.bashrc && TEST_NAMES={','.join(util.long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-hybrid-remain
# Out:
# nohup: ignoring input and appending output to 'nohup.out'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       1 import util
#       2 # 51m for short cases
#       3 # !. ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-hybrid-target
#       4 # !. ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 python eval_reduce.py wasm-hybrid-remain
#       5
#       6 # !. ~/.bashrc && TEST_NAMES={','.join(util.long_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-hybrid-target
# ----> 7 get_ipython().system(". ~/.bashrc && TEST_NAMES={','.join(util.short_case)} MAX_WORKER=8 BINARYEN_CORES=4 nohup python eval_reduce.py wasm-hybrid-remain")
#
# ...
